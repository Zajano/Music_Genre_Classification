# %%
import json
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow.keras as keras

DATASET_PATH = "data.json"

# %%
def load_data(dataset_path):
    with open(dataset_path, "r") as fp:
        data = json.load(fp)

    inputs = np.array(data["mfcc"])
    targets = np.array(data["labels"])

    print("Data successfully loaded!")

    return inputs, targets

# %%
# load the data
inputs, targets = load_data(DATASET_PATH)

# create the train/test split
x_train, x_test, y_train, y_test = train_test_split(inputs, targets, test_size=0.3)

# build network topology
model = keras.Sequential([

    # input layer
    keras.layers.Flatten(input_shape=(inputs.shape[1], inputs.shape[2])),

    # 1st dense layer
    keras.layers.Dense(512, activation="relu"),

    # 2nd dense layer
    keras.layers.Dense(256, activation="relu"),

    # 3rd dense layer
    keras.layers.Dense(64, activation="relu"),

    # output layer
    keras.layers.Dense(12, activation="softmax") # might need to change this to 10? 
])

# compile model
optimizer = keras.optimizers.Adam(learning_rate=0.0001)
model.compile(optimizer=optimizer, loss="sparse_categorical_crossentropy", metrics=["accuracy"])

model.summary()

# annnd now train model
history = model.fit(x_train, y_train, validation_data=(x_test, y_test), batch_size=32, epochs=50)
# Out:
# Data successfully loaded!
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_1 (Flatten)          (None, 1690)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 512)               865792
# _________________________________________________________________
# dense_5 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dense_6 (Dense)              (None, 64)                16448
# _________________________________________________________________
# dense_7 (Dense)              (None, 12)                780
# =================================================================
# Total params: 1,014,348
# Trainable params: 1,014,348
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 22/22 [==============================] - 1s 21ms/step - loss: 20.6857 - accuracy: 0.1569 - val_loss: 6.9514 - val_accuracy: 0.3233
# Epoch 2/50
# 22/22 [==============================] - 0s 14ms/step - loss: 4.5817 - accuracy: 0.4134 - val_loss: 4.3814 - val_accuracy: 0.4267
# Epoch 3/50
# 22/22 [==============================] - 0s 13ms/step - loss: 2.2026 - accuracy: 0.5864 - val_loss: 4.0789 - val_accuracy: 0.4733
# Epoch 4/50
# 22/22 [==============================] - 0s 12ms/step - loss: 1.5131 - accuracy: 0.7134 - val_loss: 3.3669 - val_accuracy: 0.5033
# Epoch 5/50
# 22/22 [==============================] - 0s 13ms/step - loss: 0.8110 - accuracy: 0.7820 - val_loss: 3.2305 - val_accuracy: 0.4900
# Epoch 6/50
# 22/22 [==============================] - 0s 14ms/step - loss: 0.4426 - accuracy: 0.8780 - val_loss: 3.2112 - val_accuracy: 0.5233
# Epoch 7/50
# 22/22 [==============================] - 0s 14ms/step - loss: 0.2502 - accuracy: 0.9125 - val_loss: 3.0575 - val_accuracy: 0.5233
# Epoch 8/50
# 22/22 [==============================] - 0s 15ms/step - loss: 0.2025 - accuracy: 0.9248 - val_loss: 3.1022 - val_accuracy: 0.5133
# Epoch 9/50
# 22/22 [==============================] - 0s 13ms/step - loss: 0.2413 - accuracy: 0.9125 - val_loss: 3.0231 - val_accuracy: 0.5433
# Epoch 10/50
# 22/22 [==============================] - 0s 13ms/step - loss: 0.1128 - accuracy: 0.9650 - val_loss: 3.0242 - val_accuracy: 0.5533
# Epoch 11/50
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0717 - accuracy: 0.9861 - val_loss: 2.9665 - val_accuracy: 0.5433
# Epoch 12/50
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0502 - accuracy: 0.9832 - val_loss: 2.9301 - val_accuracy: 0.5700
# Epoch 13/50
# 22/22 [==============================] - 1s 24ms/step - loss: 0.0241 - accuracy: 0.9974 - val_loss: 2.8691 - val_accuracy: 0.5767
# Epoch 14/50
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0179 - accuracy: 0.9970 - val_loss: 2.8817 - val_accuracy: 0.5667
# Epoch 15/50
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0120 - accuracy: 1.0000 - val_loss: 2.8537 - val_accuracy: 0.5800
# Epoch 16/50
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0106 - accuracy: 1.0000 - val_loss: 2.8588 - val_accuracy: 0.5767
# Epoch 17/50
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0085 - accuracy: 1.0000 - val_loss: 2.8635 - val_accuracy: 0.5933
# Epoch 18/50
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0088 - accuracy: 1.0000 - val_loss: 2.8558 - val_accuracy: 0.5867
# Epoch 19/50
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0085 - accuracy: 1.0000 - val_loss: 2.8628 - val_accuracy: 0.5967
# Epoch 20/50
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 2.8558 - val_accuracy: 0.5967
# Epoch 21/50
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 2.8606 - val_accuracy: 0.6000
# Epoch 22/50
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 2.8582 - val_accuracy: 0.5933
# Epoch 23/50
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 2.8672 - val_accuracy: 0.6000
# Epoch 24/50
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 2.8561 - val_accuracy: 0.5933
# Epoch 25/50
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 2.8671 - val_accuracy: 0.6000
# Epoch 26/50
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 2.8550 - val_accuracy: 0.6033
# Epoch 27/50
# 22/22 [==============================] - 0s 21ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 2.8667 - val_accuracy: 0.6067
# Epoch 28/50
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 2.8720 - val_accuracy: 0.6000
# Epoch 29/50
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 2.8600 - val_accuracy: 0.6067
# Epoch 30/50
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 2.8665 - val_accuracy: 0.6000
# Epoch 31/50
# 22/22 [==============================] - 1s 25ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 2.8665 - val_accuracy: 0.6033
# Epoch 32/50
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 2.8692 - val_accuracy: 0.6000
# Epoch 33/50
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 2.8689 - val_accuracy: 0.6033
# Epoch 34/50
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 2.8702 - val_accuracy: 0.6033
# Epoch 35/50
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 2.8737 - val_accuracy: 0.6067
# Epoch 36/50
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 2.8719 - val_accuracy: 0.6067
# Epoch 37/50
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 2.8688 - val_accuracy: 0.6100
# Epoch 38/50
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 2.8701 - val_accuracy: 0.6067
# Epoch 39/50
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 2.8707 - val_accuracy: 0.6067
# Epoch 40/50
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 2.8747 - val_accuracy: 0.6100
# Epoch 41/50
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 2.8737 - val_accuracy: 0.6100
# Epoch 42/50
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 2.8764 - val_accuracy: 0.6100
# Epoch 43/50
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 2.8819 - val_accuracy: 0.6100
# Epoch 44/50
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 2.8770 - val_accuracy: 0.6133
# Epoch 45/50
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 2.8779 - val_accuracy: 0.6100
# Epoch 46/50
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 2.8705 - val_accuracy: 0.6100
# Epoch 47/50
# 22/22 [==============================] - 0s 20ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 2.8809 - val_accuracy: 0.6133
# Epoch 48/50
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 2.8798 - val_accuracy: 0.6133
# Epoch 49/50
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 2.8776 - val_accuracy: 0.6100
# Epoch 50/50
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 2.8795 - val_accuracy: 0.6100
